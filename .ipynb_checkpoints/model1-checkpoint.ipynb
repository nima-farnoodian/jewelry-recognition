# %% [markdown]
# # A simple baseline model with ConvNet

# %% [markdown]
# ## Achieved accuracy 85% on the test dataset

# %% [markdown]
# ## Accomplished by Atefeh Bahrami

# %%
from keras.preprocessing.image import ImageDataGenerator
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import sys

import tensorflow as tf
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, Dropout
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers import Flatten
from keras.layers import Dense
import os
import sys
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
evaluate_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    'dataset/training', target_size=(32, 32), batch_size=25, class_mode='binary')
test_generator = test_datagen.flow_from_directory(
    'dataset/test', target_size=(32, 32), batch_size=25, class_mode='binary')
# Out:
# Found 3586 images belonging to 2 classes.
# Found 480 images belonging to 2 classes.

# %%
classifier = Sequential()

classifier.add(Conv2D(32, (3, 3), input_shape=(
    32, 32, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

classifier.add(Flatten())

classifier.add(Dropout(0.2))

classifier.add(Dense(units=256, activation='relu'))

classifier.add(Dropout(0.2))

classifier.add(Dense(units=128, activation='relu'))

classifier.add(Dropout(0.2))


classifier.add(Dense(units=1, activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               1843456
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,877,377
# Trainable params: 1,877,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(
    optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# fit generate our model
score_fit = classifier.fit_generator(train_generator,
                                     epochs=10, steps_per_epoch=15,validation_data=test_generator, validation_steps=15)

# print("Train generator indices : ", train_generator.class_indices)
score = classifier.evaluate_generator(test_generator, 32)

print("Evaluation :  ===============================================================")
print("Loss : ", score[0])
print("Accuracy : ", score[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
#  9/15 [=================>............] - ETA: 0s - loss: 0.8177 - accuracy: 0.5009
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 15/15 [==============================] - 4s 225ms/step - loss: 0.7685 - accuracy: 0.5415 - val_loss: 0.6941 - val_accuracy: 0.5227
# Epoch 2/10
# 15/15 [==============================] - 3s 215ms/step - loss: 0.5800 - accuracy: 0.7032 - val_loss: 0.4661 - val_accuracy: 0.7867
# Epoch 3/10
# 15/15 [==============================] - 3s 239ms/step - loss: 0.4643 - accuracy: 0.7937 - val_loss: 0.6565 - val_accuracy: 0.7467
# Epoch 4/10
# 15/15 [==============================] - 3s 218ms/step - loss: 0.4114 - accuracy: 0.8249 - val_loss: 0.4313 - val_accuracy: 0.8107
# Epoch 5/10
# 15/15 [==============================] - 4s 240ms/step - loss: 0.4932 - accuracy: 0.7614 - val_loss: 0.4279 - val_accuracy: 0.8533
# Epoch 6/10
# 15/15 [==============================] - 3s 224ms/step - loss: 0.3803 - accuracy: 0.8357 - val_loss: 0.4174 - val_accuracy: 0.8293
# Epoch 7/10
# 15/15 [==============================] - 3s 224ms/step - loss: 0.2625 - accuracy: 0.8963 - val_loss: 0.6339 - val_accuracy: 0.8213
# Epoch 8/10
# 15/15 [==============================] - 3s 231ms/step - loss: 0.3711 - accuracy: 0.8567 - val_loss: 0.4581 - val_accuracy: 0.8533
# Epoch 9/10
# 15/15 [==============================] - 3s 224ms/step - loss: 0.3535 - accuracy: 0.8743 - val_loss: 0.5074 - val_accuracy: 0.7920
# Epoch 10/10
# 15/15 [==============================] - 3s 219ms/step - loss: 0.3279 - accuracy: 0.8558 - val_loss: 0.4013 - val_accuracy: 0.8453
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
# Evaluation :  ===============================================================
# Loss :  0.3849993944168091
# Accuracy :  0.8500000238418579

# %%
classifier.save("Conve_v1.h5")

# %%
from tensorflow import keras
classifier = keras.models.load_model("Conve_v1.h5")

# %%
evaluate_datagen = ImageDataGenerator(rescale=1./255)
sample_generator = evaluate_datagen.flow_from_directory(
    'dataset/example', target_size=(32, 32), batch_size=1, class_mode='binary')
# Out:
# Found 12 images belonging to 2 classes.

# %%
score = classifier.evaluate_generator(sample_generator)
print("Loss : ", score[0])
print("Accuracy : ", score[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Loss :  0.6235597729682922
# Accuracy :  0.75

# %%
from PIL import Image
import numpy as np
from skimage import transform
def load(filename):
    np_image = Image.open(filename)
    np_image = np.array(np_image).astype('float32')/255
    np_image = transform.resize(np_image, (32, 32, 3))
    np_image = np.expand_dims(np_image, axis=0)
    return np_image

# %%
image = load("./test_to_show/o1.jpg")
classifier.predict(image)
# Out:
# array([[0.83536345]], dtype=float32)

# %%
cls[0]

# %%
mypath="./test_to_show/"
from os import listdir
from os.path import isfile, join
images = [f for f in listdir(mypath) if isfile(join(mypath, f))]
count=0
plt.figure(figsize=(14, 10))
for img in images:
    test_image=Image.open(mypath+img)
    inp_org=np.array(test_image)
    #inp=np.array(test_image.resize((32,32)))
    #inp=inp
    #inp=inp.reshape((1,32,32,3))
    image = load(mypath+img)
    #classifier.predict(image)
    cls=classifier.predict(image)
    if np.round(cls[0])==0:
        lbl="Jewelry"
    elif np.round(cls[0])==1:
        lbl="Other"
    #plot1 = plt.figure(count)
    ax = plt.subplot(6, 3, count + 1)
    plt.imshow(inp_org)
    plt.title(lbl)
    plt.axis("off")
    count+=1
